# %%
import sys
from pyprojroot import here
sys.path.insert(0, str(here()))

# %%
from src.synthetic_generator import SyntheticSceneGenerator
from src.horizon_visualization import plot_synthetic_samples

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
output_dir = here() / "data" / "synthetic_dataset"
images_dir = output_dir / "images"
masks_dir = output_dir / "masks"

images_dir.mkdir(parents=True, exist_ok=True)
masks_dir.mkdir(parents=True, exist_ok=True)

# %%
generator = SyntheticSceneGenerator(
    dem_path=str(here() / "data/digital_elevation_model/dem_30m.tif"),
    sat_path=str(here() / "data/satellite_imagery/satellite_texture_cropped.png"),
    bounds_path=str(here() / "data/satellite_imagery/satellite_texture_bounds_cropped.npz")
)

# %%
viewpoints = np.load(here() / "data/digital_elevation_model/viewpoints_mapping.npy")

# %%
generator.generate_dataset(
    viewpoints=viewpoints,
    target_samples=15,
    images_dir=images_dir,
    masks_dir=masks_dir,
    gt_json_path=gt_json_path
)

# %%
plot_synthetic_samples(images_dir, masks_dir)
