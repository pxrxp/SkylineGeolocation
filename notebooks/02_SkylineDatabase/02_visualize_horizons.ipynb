# %%
from pyprojroot import here
import sys
sys.path.insert(0, str(here()))

# %%
from src.horizon_visualization import SkylineHorizonExplorer

# %%
dem_file = here() / "data" / "digital_elevation_model" / "dem_30m.tif"
db_file = here() / "notebooks" / "02_SkylineDatabase" / "output" / "skyline_db.parquet"

# %%
explorer = SkylineHorizonExplorer(dem_file=dem_file, db_file=db_file)
explorer.print_summary()
# Out:
# DEM: /home/admin/SkylineGeolocation/data/digital_elevation_model/dem_30m.tif
# DB: /home/admin/SkylineGeolocation/notebooks/02_SkylineDatabase/output/skyline_db.parquet
# Viewpoints: 1,338,650
# Grid size: 1002 x 1336

# %%
explorer.interactive_widget()
