# %% [markdown]
# # Downloading the dataset

# %%
import sys
from pyprojroot import here
sys.path.insert(0, str(here()))

import os

# %% [markdown]
# We create a separate folder for our GeoPose3K dataset. This separates it from the synthetic data.

# %%
os.makedirs(here() / "data/geopose3k", exist_ok=True)

# %% [markdown]
# GeoPose3K dataset has split the images into train, test and validation sets. This information is in the `geoPose3K_splits.zip` file.

# %%
splits_zip = here() / "data/geoPose3K_splits.zip"
splits_url = "https://cphoto.fit.vutbr.cz/geoPose3K/data/geoPose3K_splits.zip"

# %%
import zipfile
import urllib.request

# %%
if not os.path.exists(here() / "data/geopose3k/splits"):
    if not os.path.exists(splits_zip):
        print("Downloading train/test splits...")
        urllib.request.urlretrieve(splits_url, splits_zip)

    print("Extracting splits...")
    with zipfile.ZipFile(splits_zip, "r") as zip_ref:
        zip_ref.extractall(here() / "data/geopose3k/splits")

    os.remove(splits_zip)
    print("Splits extracted.")

# %%
dataset_tar = here() / "data/geoPose3K_final_publish.tar.gz"
dataset_url = "http://merlin.fit.vutbr.cz/elevation/geoPose3K_final_publish.tar.gz"

# %%
import tarfile

# %%
if not os.path.exists(here() / "data/geopose3k/final_publish"):
    if not os.path.exists(dataset_tar):
        print("Downloading full GeoPose3K dataset (This may take some time)...")
        urllib.request.urlretrieve(dataset_url, dataset_tar)

    print("Extracting dataset...")
    with tarfile.open(dataset_tar, "r:gz") as tar_ref:
        tar_ref.extractall(here() / "data/geopose3k")

    os.remove(dataset_tar)
    print("Dataset extracted.")
# Out:
# Extracting dataset...
# Dataset extracted.

# %% [markdown]
# This is our complete GeoPose3K dataset:

# %%
base_dir = here() / "data/geopose3k/geoPose3K_final_publish"

# %% [markdown]
# <hr/>
#
# # Understanding the dataset
#
# Let's try to understand the structure of dataset.

# %%
with open(here() / "data/geopose3k/geoPose3K_final_publish/README", "r") as f:
    print(f.read())
# Out:
#    _____            _____               ____  _  __
#   / ____|          |  __ \             |___ \| |/ /
#  | |  __  ___  ___ | |__) |__  ___  ___  __) | ' /
#  | | |_ |/ _ \/ _ \|  ___/ _ \/ __|/ _ \|__ <|  <
#  | |__| |  __/ (_) | |  | (_) \__ \  __/___) | . \
#   \_____|\___|\___/|_|   \___/|___/\___|____/|_|\_\
#
# ================================================================================
# authors:        Jan Brejcha <brejchaja@gmail.com>
#                 Martin Čadík <cadik@fit.vut.cz, cadikm@centrum.cz>
# affiliation:    Brno University of Technology,
#                 Faculty of Information Technology
# ================================================================================
#
# GeoPose3K is a dataset of more than three thousand photos with precise
# annotations of camera position and orientation. Each photo is accompanied
# with additional metadata rendered from a digital elevation model, specifically
# depth, normals w.r.t. cardinal direction and camera, semantic labels obtained
# from a GIS database (forest, glacier, bodies of water, etc.), and simulation
# of local illumination through the day.
#
# Dataset organization
# ====================
# Each image in the dataset is located in a separate directory.
#
# Structure: <image directory>/*
# - cyl:      contains all available maps under cylindric projection.
# - pinhole:  contains all available maps under perspective projection (fits the
#             original image)
# - photo.<jpg|jpeg|png>: the original image
# - info.txt  the file containing camera orientation, position and field-of-view
#             (FOV) annotation. All angles are in radians, elevation in meters,
#             and geo-coordinates are in degrees, using WGS84.
#
#             Each line contains annotations in following order:
#
#             (1) <MANUAL|AUTOMATIC> - type of the annotation, MANUAL for manually
#             annotated, AUTOMATIC for annotations estimated automatically using
#             weighted alignment metric [1].
#
#             (2) <yaw> <pitch> <roll> - camera orientation. Yaw angle is in range
#             <-PI, PI>, zero corresponds to the west direction (270 degrees) and
#             increases counter-clockwise. Pitch is in range <-PI/2, PI/2>, with
#             zero at horizon and PI/2 at zenith. Roll is in range <-PI, PI>,
#             with zero indicating leveled image, with increasing value for
#             counter-clockwise rotation.
#
#             (3) <estimated latitude> - latitude that was estimated using the
#             method defined at line (1).
#
#             (4) <estimated longitude> - longitude that was estimated using the
#             method defined at line (1).
#
#             (5) <estimated elevation> - elevation according to our digital
#             elevation model at the estimated latitude/longitude.
#             We use digital elevation model of Alps with 24 meters spaced samples
#             from http://www.viewfinderpanoramas.org
#
#             (6) <estimated FOV> - field-of-view that was estimated using the
# 			method defined at line (1).
#
#             (7) <original latitude> - latitude that comes with the original
#             photo.
#
#             (8) <original longitude> - longitude that comes with the original
#             photo.
#
#             (9) <original elevation> - elevation according to our digital
#             elevation model at the original latitude/longitude.
#
#             (10) <original FOV> - field-of-view that comes with the original
#             photo.
#
# - license.txt: license for the photo.<jpg|jpeg|png> and cyl/photo_crop.jpg
#                files.
#
# GeoPose3K Splits
# ================
# We optimized training, validation and testing splits to maximize the
# geographic distance between the sets and to contain similar distribution
# of semantic segment classes. Complete definition of our splits can be
# found in the attached text files:
# - training split:   geoPose3K_final_train.txt
# - validation split: geoPose3K_final_val.txt
# - testing split:    geoPose3K_final_test.txt
#
# Depth Maps (distance_crop.pfm)
# ==============================
# Depth maps are stored in portable float maps (pfm) in meters. To view them,
# pfstools can be used: http://pfstools.sourceforge.net/download.html. To reduce
# their size, each pfm file is compressed using gzip.
#
# Semantic labels (labels_crop.png)
# =================================
# Semantic labels were obtained from OpenStreetMap. Official definition of the
# classes can be found at: http://wiki.openstreetmap.org/wiki/Map_Features#Natural
#
# In the dataset, following classes are encoded using RGB color scheme:
#
# class,      r,      g,      b,      a
# ----------------------------------------
# forest,     0.46f,  0.86f,  0.39f,  1.0f
# glacier,    0.61f,  0.85f,  0.86f,  1.0f
# water,      0.01f,  0.53f,  0.86f,  1.0f
# cliff,      0.38f,  0.35f,  0.34f,  1.0f
# bare_rock,  0.94f,  0.95f,  0.78f,  1.0f
# scree,      0.82f,  0.95f,  0.78f,  1.0f
# wood,       0.46f,  0.86f,  0.39f,  1.0f
# moor,       0.94f,  0.95f,  0.78f,  1.0f
# fell,       0.80f,  0.73f,  0.74f,  1.0f
# grassland,  0.72f,  0.86f,  0.41f,  1.0f
# shingle,    0.90f,  0.95f,  0.53f,  1.0f
# sinkhole,   0.38f,  0.38f,  0.38f,  1.0f
# sky,        0.00f,  0.00f,  0.00f,  1.0f
#
# Illumination simulation (pano_crop_<hour>.jpg)
# ==============================================
# Illumination approximation was simulated hour by hour from 4 am till 9pm on
# 21st June, when the days are the longest during a year. The illumination
# simulation was calculated using a local illumination model, so that it does
# not contain casted shadows. Default terrain color was set to (RGBA):
# 0.5f, 0.5f, 0.5f, 1.0.
#
# Normals (normalsCamera_crop.png, normalsWorld_crop.png)
# =======================================================
# There are normals w.r.t camera (normalsCamera_crop.png), and cardinal direction
# (normalsWorld_crop.png). Both types of normals were encoded into the image,
# so that original normals were rescaled from range <-1, 1> into the range <0, 1>.
#
# License
# =======
# The dataset excluding all the photo.<jpg|jpeg|png> and photo_crop.jpg files
# is distributed under Creative Commons Attribution-NonCommercial 4.0
# (CC BY-NC 4.0) license. For files named photo.<jpg|jpeg|png> and
# cyl/photo_crop.jpg the license written in license.txt in corresponding
# subdirectory applies.
#
# Cite as
# =======
# BREJCHA Jan and ČADÍK Martin. GeoPose3K: Mountain Landscape Dataset for Camera
# Pose Estimation in Outdoor Environments. Image and Vision Computing.
# Washington: Elsevier Science, 2017, ISSN 1433-7541, doi: 10.1016/j.imavis.2017.05.009
#
# References
# ==========
# [1] BREJCHA Jan and ČADÍK Martin. GeoPose3K: Mountain Landscape Dataset for
# Camera Pose Estimation in Outdoor Environments. Image and Vision Computing.
# Washington: Elsevier Science, 2017, ISSN 1433-7541, doi: 10.1016/j.imavis.2017.05.009

# %% [markdown]
# Let's see how the train/test/validation split information is given:

# %%
train_file_path = None
for root, dirs, files in os.walk(here() / "data/geopose3k"):
    if "geoPose3K_final_train.txt" in files:
        train_file_path = os.path.join(root, "geoPose3K_final_train.txt")
        break

if train_file_path:
    print(f"Reading first 5 lines of '{train_file_path}':\n")
    with open(train_file_path, "r") as f:
        for _ in range(5):
            print(f.readline().strip())
else:
    print("geoPose3K_final_train.txt not found.")
# Out:
# Reading first 5 lines of 'data/geopose3k/geoPose3K_final_publish/geoPose3K_final_train.txt':
#
# 28488116812_f5a57ca0f6_k
# 28561570606
# eth_ch1_1332166_01024
# eth_ch1_2011-04-30_18:37:52_01024
# eth_ch1_2011-04-30_18:40:20_01024

# %%
sample_folder = os.path.join(base_dir, "28488116812_f5a57ca0f6_k")
mask_path = os.path.join(sample_folder, "pinhole/labels_crop.png")

if os.path.exists(mask_path):
    mask_arr = np.array(Image.open(mask_path))
    print(f"Unique pixel values in 'labels_crop.png': {np.unique(mask_arr)}")
else:
    print("Mask file not found at the expected path.")
# Out:
# Unique pixel values in 'labels_crop.png': [  0  99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115
#  116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133
#  134 135 136 137 138 139 140 141 142 143 144 145 146 147 148 149 150 151
#  152 153 154 155 156 157 158 159 160 161 162 163 164 165 166 167 168 169
#  170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187
#  188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 205
#  206 207 208 209 210 211 212 213 214 215 216 217 218 219 220 221 222 223
#  224 225 226 227 228 229 230 231 232 233 234 235 236 237 238 239 240 241
#  242 243 244 245 246 247 248 249 250 251 252 253 254 255]

# %% [markdown]
# The values seem to be between 0 and 255.

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
sample = "eth_ch1_04032011388_01024"
sample_img_path = os.path.join(base_dir, sample, "photo.jpg")
sample_mask_path = os.path.join(base_dir, sample, "pinhole", "labels_crop.png")

# %%
if os.path.exists(sample_img_path):
    plt.imshow(Image.open(sample_img_path))
    plt.show()

# %%
if os.path.exists(sample_mask_path):
    plt.imshow(Image.open(sample_mask_path), cmap='gray')
    plt.show()

# %% [markdown]
# The dataset neatly gives the skymasks we require.
# `0 (black) = sky`
